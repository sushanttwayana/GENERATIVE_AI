# %%
import os
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
llm = ChatGroq(model="openai/gpt-oss-120b", temperature=0.3)
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x00000279C0691D20>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000279C082FE50>, model_name='openai/gpt-oss-120b', temperature=0.3, model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage, SystemMessage
import requests
from  langchain_core.tools import InjectedToolArg
from typing import Annotated

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()


results = search_tool.invoke('Top news in footaball today')

results
# Out:
# 'April 23, 2025 - Derrick Lewis’ X-Rated Comment About Wife After UFC Nashville Win Give Me Sport 11:48 Sun, 13 Jul Football · ‘Here We Go’ – Fabrizio Romano Says West Ham Agree Deal for £19m Star Give Me Sport 11:44 Sun, 13 Jul West Ham · Manchester United appoint five new staff members as Carrington plan takes shape Manchester Evening News: Manchester United 11:38 Sun, 13 Jul Manchester United · Manchester United now face £86m striker blow as Newcastle United reportedly ramp up transfer pursuit United In Focus 11:30 Sun, 13 Jul Newcastle United 2 weeks ago - FBS Football · CFP bracket revealed; Indiana lands top seed, Miami jumps Notre Dame · CFP Bracket · FBS Football · How the nation is picking the 2025 College Football Playoff bracket · FBS football · Here are the most popular upset picks ... 6 hours ago - From player opt-outs to full-team bailouts, this season’s bowl slate offers unpredictability, odd matchups, interim coaches and absurdity. Playoff contenders brace for a volatile week as coaching exits, league imbalances and head-to-head debates cloud the committee’s choices. A surprising coaching courtship collides with a College Football Playoff race promising maximum drama. The Big Ten was also quietly busy making moves after the regular season ended, while the American is paying the price for its success. The top QB in the sport becomes Indiana’s first winner of college football’s top award beating out a deep field. 14 hours ago - The latest news and breaking lines from the world of football... 9 hours ago - And the men’s goal prize goes to Santiago Montiel, who’s taken the 2025 FIFA Puskás Award for a ridiculous overhead kick for Independiente against Independiente Rivadavia in Argentina’s top flight back in May. He’s also the second Argentinian in a row to win the award, following Alejandro Garnacho in 2024. ... Goal-of-the-night energy on the women’s side: Lizbeth Ovalle wins the 2025 FIFA Marta Award for her outrageous scorpion-kick finish for Tigres against Guadalajara in Liga MX Femenil in March. It’s the prize that recognises the best goal in women’s football and was introduced last year when Brazil star Marta won the inaugural edition and had the award named for her.'

# %%
from langgraph.prebuilt import create_react_agent
# from langchain import hub
from langchain_classic.agents import AgentExecutor

# %%
from langchainhub import Client

client = Client()
prompt = client.pull("hwchase17/react")

# %%
# Step 3: Create the ReAct agent manually with the pulled prompt
agent = create_react_agent(
    model=llm,
    tools=[search_tool],
    prompt=prompt
)
# Out:
# C:\Temp\ipykernel_28648\717883715.py:2: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(

# %%
## wrap with AgentExecutor
agent_executor = AgentExecutor(
    agent=agent,
    tools=[search_tool],
    verbose=True
)

# %%
# Invoke
response = agent_executor.invoke({"input": "3 ways to reach Kathmandu to Pokhara"})
print(response)
# Out:
# > Entering new AgentExecutor chain...
# Error in StdOutCallbackHandler.on_agent_action callback: AttributeError("'str' object has no attribute 'log'")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Invoke
# ----> 2 response = agent_executor.invoke({"input": "3 ways to reach Kathmandu to Pokhara"})
#       3 print(response)
#
# File c:\Users\Vanilla\anaconda3\envs\myenv\lib\site-packages\langchain_classic\chains\base.py:167, in Chain.invoke(self, input, config, **kwargs)
#     164 try:
#     165     self._validate_inputs(inputs)
#     166     outputs = (
# --> 167         self._call(inputs, run_manager=run_manager)
#     168         if new_arg_supported
#     169         else self._call(inputs)
#     170     )
#     172     final_outputs: dict[str, Any] = self.prep_outputs(
#     173         inputs,
#     174         outputs,
#     175         return_only_outputs,
#     176     )
#     177 except BaseException as e:
#
# File c:\Users\Vanilla\anaconda3\envs\myenv\lib\site-packages\langchain_classic\agents\agent.py:1605, in AgentExecutor._call(self, inputs, run_manager)
#    1603 # We now enter the agent loop (until it returns something).
#    1604 while self._should_continue(iterations, time_elapsed):
# -> 1605     next_step_output = self._take_next_step(
#    1606         name_to_tool_map,
#    1607         color_mapping,
#    1608         inputs,
#    1609         intermediate_steps,
#    1610         run_manager=run_manager,
#    1611     )
#    1612     if isinstance(next_step_output, AgentFinish):
#    1613         return self._return(
#    1614             next_step_output,
#    1615             intermediate_steps,
#    1616             run_manager=run_manager,
#    1617         )
#
# File c:\Users\Vanilla\anaconda3\envs\myenv\lib\site-packages\langchain_classic\agents\agent.py:1305, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1296 def _take_next_step(
#    1297     self,
#    1298     name_to_tool_map: dict[str, BaseTool],
#    (...)
#    1302     run_manager: CallbackManagerForChainRun | None = None,
#    1303 ) -> AgentFinish | list[tuple[AgentAction, str]]:
#    1304     return self._consume_next_step(
# -> 1305         list(
#    1306             self._iter_next_step(
#    1307                 name_to_tool_map,
#    1308                 color_mapping,
#    1309                 inputs,
#    1310                 intermediate_steps,
#    1311                 run_manager,
#    1312             ),
#    1313         ),
#    1314     )
#
# File c:\Users\Vanilla\anaconda3\envs\myenv\lib\site-packages\langchain_classic\agents\agent.py:1388, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1386     yield agent_action
#    1387 for agent_action in actions:
# -> 1388     yield self._perform_agent_action(
#    1389         name_to_tool_map,
#    1390         color_mapping,
#    1391         agent_action,
#    1392         run_manager,
#    1393     )
#
# File c:\Users\Vanilla\anaconda3\envs\myenv\lib\site-packages\langchain_classic\agents\agent.py:1405, in AgentExecutor._perform_agent_action(self, name_to_tool_map, color_mapping, agent_action, run_manager)
#    1403     run_manager.on_agent_action(agent_action, color="green")
#    1404 # Otherwise we lookup the tool
# -> 1405 if agent_action.tool in name_to_tool_map:
#    1406     tool = name_to_tool_map[agent_action.tool]
#    1407     return_direct = tool.return_direct
#
# AttributeError: 'str' object has no attribute 'tool'
