# %% [markdown]
# ## Problem of Manually creating the componentss of the langchain components

# %%
import random

class FakeLLM:

    def __init__(self):
        print("LLM Created")
        
    
    
    def predict(self, prompt):
        
        
        respone_list = [
            "Kathmandu is the captial of Nepal",
            "AI Stands for Artifical Intelligence",
            "Lumbini Lions Won the 2nd NPL Trophy",
        ]
        
        return {"response": random.choice(respone_list)}

# %%
llm = FakeLLM()

llm.predict("what is the captial of Nepal")
# Out:
# LLM Created
# {'response': 'Kathmandu is the captial of Nepal'}

# %%
### Prompt Template

class DummyPromptTemplate:
    
    def __init__(self, template, input_variables):
        
        self.template = template
        self.input_variables = input_variables
        
    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
template = DummyPromptTemplate(
    template="Write a {length} poem about {topic}",
    input_variables=['length','topic']
)

template.format({'length' : "short", 'topic': "Nepal"})
# Out:
# 'Write a short poem about Nepal'

# %%
prompt = template.format({'length' : "short", 'topic': "Nepal"})

# %%
llm = FakeLLM()
llm.predict(prompt)
# Out:
# LLM Created
# {'response': 'Kathmandu is the captial of Nepal'}

# %% [markdown]
# ### Creating LLM Chains manually

# %%
class DummyLLMChain:
    
    def __init__(self, llm , prompt):
        self.llm = llm
        self.prompt = prompt
        
    
    def run(self, input_dict):
        
        final_prompt = self.prompt.format(input_dict)
        result = self.llm.predict(final_prompt)
        
        return result['response']

# %%
template = DummyPromptTemplate(
    template="Write a {length} poem about {topic}",
    input_variables=['length','topic']
)

# %%
llm = FakeLLM()

chain = DummyLLMChain(llm, template)

chain.run({'length': 'short', 'topic': 'Nepal'})
# Out:
# LLM Created
# 'Kathmandu is the captial of Nepal'
