# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## This file consists  of only imgaes to make clear

# %% [markdown]
# #### Runnable Primitives
#
# ![image.png](attachment:image.png)

# %% [markdown]
#  #### Types of PdfLoaders in Langchain
#
#  ![image.png](attachment:image.png)

# %% [markdown]
# ### glob in drectory laoder
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Document-Structured-Based
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **https://chunkviz.up.railway.app/**

# %% [markdown]
# ### BuiltIn Tools

# %% [markdown]
# ![image.png](attachment:image.png)
